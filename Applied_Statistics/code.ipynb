# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# %% [markdown]
# # Programming Assignment: <br> **Predicting movie revenue using linear regression**

# %% [markdown]
# ## 1.

# %%
movie_revenues = pd.read_csv('movie_revenues.csv')

data = movie_revenues[['title', 'budget', 'runtime', 'popularity', 'revenue']]
data['is_en'] = movie_revenues['original_language'].apply(lambda x: 1 if x == 'en' else 0)

data.dropna(inplace=True)
Xcols = data.columns.difference(['revenue', 'title'])
X = data.loc[:, Xcols]
y = data['revenue']

data
# Out:
#                                          title    budget  runtime  popularity  \
# 0                       Hot Tub Time Machine 2  14000000     93.0    6.575393
# 1     The Princess Diaries 2: Royal Engagement  40000000    113.0    8.248895
# 2                                     Whiplash   3300000    105.0   64.299990
# 3                                      Kahaani   1200000    122.0    3.174936
# 4                                   Marine Boy         0    118.0    1.148070
# ...                                        ...       ...      ...         ...
# 2995                                   Chasers         0    102.0    9.853270
# 2996                          We Are the Best!         0    102.0    3.727996
# 2997                   The Long Kiss Goodnight  65000000    120.0   14.482345
# 2998                          Along Came Polly  42000000     90.0   15.725542
# 2999                                 Abduction  35000000    106.0   10.512109
#
#         revenue  is_en
# 0      12314651      1
# 1      95149435      1
# 2      13092000      1
# 3      16000000      0
# 4       3923970      0
# ...         ...    ...
# 2995    1596687      1
# 2996     180590      0
# 2997   89456761      1
# 2998  171963386      1
# 2999   82087155      1
#
# [2998 rows x 6 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
print('Correlation coefficients:')
for x in X:
    print(f'{x}: {y.corr(X[x])}')

sns.pairplot(data, x_vars=X.columns, y_vars=['revenue'], height=3, kind='reg');
# Out:
# Correlation coefficients:
# budget: 0.7529244561869333
# is_en: 0.14163124487140186
# popularity: 0.4613468767475681
# runtime: 0.2163801301814721

# %% [markdown]
# It seems that budget is the explanatory variable most strongly associated with the revenue, since it has the highest correlation coefficient and we can see a trend in the scatter plot.

# %% [markdown]
# ## 2.

# %% [markdown]
# Let's try to construct some new features and fit a multiple linear regression model. Specifically, we will add:
# - has_actor: 1 if the movie casts one or more of a handful of popular actors, 0 otherwise
# - has_director: 1 if one or more of a handful of popular directors are involved, 0 otherwise
# - female_pct: the percentage of female actresses in the cast

# %%
actors = ['Christian Bale', 'Tom Hardy', 'Cilian Murphy', 'Scarlett Johansson', 'Johnny Depp', 'Will Smith', 'Ryan Gosling']
has_actor = movie_revenues['cast'].str.contains('|'.join(actors))
data['has_actor'] = has_actor[data.index].astype(float)

directors = ['Christopher Nolan', 'Martin Scorcese', 'Steven Spielberg', 'Quentin Tarantino']
has_director = movie_revenues['crew'].str.contains('|'.join(directors))
data['has_director'] = has_director[data.index].astype(float)

females = movie_revenues['cast'].str.count(f"'gender': 1")
males = movie_revenues['cast'].str.count(f"'gender': 2")
female_pct = females / (females + males)
data['female_pct'] = female_pct[data.index]

data.dropna(inplace=True)
data = data.astype({'has_actor': int, 'has_director': int})

Xcols = data.columns.difference(['revenue', 'title'])
X = data.loc[:, Xcols]
y = data['revenue']

data
# Out:
#                                          title    budget  runtime  popularity  \
# 0                       Hot Tub Time Machine 2  14000000     93.0    6.575393
# 1     The Princess Diaries 2: Royal Engagement  40000000    113.0    8.248895
# 2                                     Whiplash   3300000    105.0   64.299990
# 3                                      Kahaani   1200000    122.0    3.174936
# 4                                   Marine Boy         0    118.0    1.148070
# ...                                        ...       ...      ...         ...
# 2995                                   Chasers         0    102.0    9.853270
# 2996                          We Are the Best!         0    102.0    3.727996
# 2997                   The Long Kiss Goodnight  65000000    120.0   14.482345
# 2998                          Along Came Polly  42000000     90.0   15.725542
# 2999                                 Abduction  35000000    106.0   10.512109
#
#         revenue  is_en  has_actor  has_director  female_pct
# 0      12314651      1          0             0    0.444444
# 1      95149435      1          0             0    0.500000
# 2      13092000      1          0             0    0.350000
# 3      16000000      0          0             0    0.333333
# 4       3923970      0          0             0    0.000000
# ...         ...    ...        ...           ...         ...
# 2995    1596687      1          0             0    0.214286
# 2996     180590      0          0             0    0.500000
# 2997   89456761      1          0             0    0.307692
# 2998  171963386      1          0             0    0.360000
# 2999   82087155      1          0             0    0.321429
#
# [2927 rows x 9 columns]

# %% [markdown]
# It may seem that there are no movies with those directors or actors, however this is not the case:

# %%
print(data[['has_director', 'has_actor']].sum())
data[data['title'] == 'The Dark Knight']
# Out:
# has_director    42
# has_actor       72
# dtype: int64
#                 title     budget  runtime  popularity     revenue  is_en  \
# 1673  The Dark Knight  185000000    152.0  123.167259  1004558444      1
#
#       has_actor  has_director  female_pct
# 1673          1             1    0.148148

# %%
cols = ['female_pct', 'has_actor', 'has_director']
print('Correlation coefficients:')
for x in cols:
    print(f'{x}: {y.corr(X[x])}')
sns.pairplot(data, x_vars=cols, y_vars=['revenue'], height=3, kind='reg');
# Out:
# Correlation coefficients:
# female_pct: -0.04264429484249335
# has_actor: 0.15999005898665236
# has_director: 0.19957579821109317

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.615
# Method:                 Least Squares   F-statistic:                     669.4
# Date:                Thu, 22 Jun 2023   Prob (F-statistic):               0.00
# Time:                        03:49:26   Log-Likelihood:                -57567.
# No. Observations:                2927   AIC:                         1.151e+05
# Df Residuals:                    2919   BIC:                         1.152e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -2.965e+07   9.87e+06     -3.004      0.003    -4.9e+07   -1.03e+07
# budget           2.4205      0.048     50.757      0.000       2.327       2.514
# female_pct    2.325e+07   8.58e+06      2.711      0.007    6.44e+06    4.01e+07
# has_actor     2.704e+07   1.02e+07      2.648      0.008    7.01e+06    4.71e+07
# has_director  8.575e+07   1.33e+07      6.443      0.000    5.97e+07    1.12e+08
# is_en        -4.495e+06   4.68e+06     -0.960      0.337   -1.37e+07    4.68e+06
# popularity    2.826e+06   1.53e+05     18.525      0.000    2.53e+06    3.13e+06
# runtime       1.113e+05   7.39e+04      1.506      0.132   -3.36e+04    2.56e+05
# ==============================================================================
# Omnibus:                     2014.887   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63387.251
# Skew:                           2.833   Prob(JB):                         0.00
# Kurtosis:                      25.083   Cond. No.                     3.69e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.69e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# We can see that is_en has a very high p-value in absolute terms as well as in comparison with the other variables, so we will eliminate it from the model and see the results.

# %%
X.drop(columns=['is_en'], inplace=True)
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.615
# Method:                 Least Squares   F-statistic:                     780.8
# Date:                Thu, 22 Jun 2023   Prob (F-statistic):               0.00
# Time:                        03:49:26   Log-Likelihood:                -57567.
# No. Observations:                2927   AIC:                         1.151e+05
# Df Residuals:                    2920   BIC:                         1.152e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -3.454e+07   8.45e+06     -4.086      0.000   -5.11e+07    -1.8e+07
# budget           2.4127      0.047     51.346      0.000       2.321       2.505
# female_pct    2.332e+07   8.58e+06      2.720      0.007    6.51e+06    4.01e+07
# has_actor     2.672e+07   1.02e+07      2.618      0.009    6.71e+06    4.67e+07
# has_director  8.544e+07   1.33e+07      6.421      0.000    5.94e+07    1.12e+08
# popularity    2.815e+06   1.52e+05     18.507      0.000    2.52e+06    3.11e+06
# runtime       1.231e+05   7.29e+04      1.689      0.091   -1.98e+04    2.66e+05
# ==============================================================================
# Omnibus:                     2015.578   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63421.757
# Skew:                           2.834   Prob(JB):                         0.00
# Kurtosis:                      25.089   Cond. No.                     3.69e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.69e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# The adjusted R-squared value, as well as the AIC and BIC criteria stay the same, so is_en doesn't seem to be very helpful and we can do without it. <br>
# The most significant explanatory variables (based on p-values) seem to be the budget, the popularity and whether one of the popular directors is involved in the movie, followed by the female percentage of the cast and whether it casts one of the popular actors.

# %% [markdown]
# Let's test the model on a couple of movies:

# %%
from IPython.display import display, HTML

def print_title(title):
    idx = data['title'] == title
    display(HTML(data[idx].to_html(index=False)))
    pred = model.predict(X[idx]).values[0]
    actual = y[idx].values[0]
    print(f"Predicted revenue for {title}: {pred:,.0f}")
    print(f"Actual revenue for {title}: {actual:,.0f}")
    print(f"Percent error: {abs(pred - actual) / actual * 100:.0f}%\n")

print_title('The Dark Knight')
print_title('The Godfather')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>title</th>
#       <th>budget</th>
#       <th>runtime</th>
#       <th>popularity</th>
#       <th>revenue</th>
#       <th>is_en</th>
#       <th>has_actor</th>
#       <th>has_director</th>
#       <th>female_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>The Dark Knight</td>
#       <td>185000000</td>
#       <td>152.0</td>
#       <td>123.167259</td>
#       <td>1004558444</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0.148148</td>
#     </tr>
#   </tbody>
# </table>
# Predicted revenue for The Dark Knight: 892,843,201
# Actual revenue for The Dark Knight: 1,004,558,444
# Percent error: 11%
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>title</th>
#       <th>budget</th>
#       <th>runtime</th>
#       <th>popularity</th>
#       <th>revenue</th>
#       <th>is_en</th>
#       <th>has_actor</th>
#       <th>has_director</th>
#       <th>female_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>The Godfather</td>
#       <td>6000000</td>
#       <td>175.0</td>
#       <td>41.109264</td>
#       <td>245066411</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.166667</td>
#     </tr>
#   </tbody>
# </table>
# Predicted revenue for The Godfather: 121,085,403
# Actual revenue for The Godfather: 245,066,411
# Percent error: 51%

# %% [markdown]
# Below we have included the code for testing whether the conditions for the multiple linear regression model are satisfied:

# %%
pred = model.predict(X)
sns.regplot(x = y, y = pred, line_kws={'color': 'red', 'alpha': 0.5})
plt.title('Actual vs. Predicted')
plt.show()

# %% [markdown]
# Instead of looking at the relationship between each individual explanatory variable and the response, we can check the linearity assumption by plotting the predicted against the actual values. <br>
# There seems to be a linear relationship between the actual and the predicted revenue, so the linearity assumption is satisfied.

# %%
sns.histplot(model.resid, kde=True)
plt.title('Distribution of Residuals')
plt.show()

# %% [markdown]
# We can see the residuals are normally distributed, so the normality assumption is satisfied.

# %%
sns.scatterplot(model.resid, alpha=0.6)
plt.plot(np.repeat(0, model.resid.index.max()), color = 'red', linestyle = '--', alpha=0.6)
plt.show()

# %% [markdown]
# We can see the residuals have constant variance, so the homoscedasticity assumption is met.

# %%
features = X.drop(columns=['const'])
corr = features.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_ff390_row0_col0, #T_ff390_row1_col1, #T_ff390_row2_col2, #T_ff390_row3_col3, #T_ff390_row4_col4, #T_ff390_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ff390_row0_col1, #T_ff390_row1_col0, #T_ff390_row1_col2, #T_ff390_row1_col3, #T_ff390_row1_col4, #T_ff390_row1_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ff390_row0_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ff390_row0_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_ff390_row0_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_ff390_row0_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ff390_row2_col0, #T_ff390_row3_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ff390_row2_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ff390_row2_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ff390_row2_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_ff390_row2_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ff390_row3_col1, #T_ff390_row5_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ff390_row3_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ff390_row3_col4, #T_ff390_row4_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ff390_row3_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ff390_row4_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ff390_row4_col1, #T_ff390_row5_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ff390_row4_col3, #T_ff390_row5_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ff390_row4_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ff390_row5_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ff390_row5_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ff390">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff390_level0_col0" class="col_heading level0 col0" >budget</th>
#       <th id="T_ff390_level0_col1" class="col_heading level0 col1" >female_pct</th>
#       <th id="T_ff390_level0_col2" class="col_heading level0 col2" >has_actor</th>
#       <th id="T_ff390_level0_col3" class="col_heading level0 col3" >has_director</th>
#       <th id="T_ff390_level0_col4" class="col_heading level0 col4" >popularity</th>
#       <th id="T_ff390_level0_col5" class="col_heading level0 col5" >runtime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff390_level0_row0" class="row_heading level0 row0" >budget</th>
#       <td id="T_ff390_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ff390_row0_col1" class="data row0 col1" >-0.100811</td>
#       <td id="T_ff390_row0_col2" class="data row0 col2" >0.158802</td>
#       <td id="T_ff390_row0_col3" class="data row0 col3" >0.160743</td>
#       <td id="T_ff390_row0_col4" class="data row0 col4" >0.344388</td>
#       <td id="T_ff390_row0_col5" class="data row0 col5" >0.226170</td>
#     </tr>
#     <tr>
#       <th id="T_ff390_level0_row1" class="row_heading level0 row1" >female_pct</th>
#       <td id="T_ff390_row1_col0" class="data row1 col0" >-0.100811</td>
#       <td id="T_ff390_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ff390_row1_col2" class="data row1 col2" >-0.001863</td>
#       <td id="T_ff390_row1_col3" class="data row1 col3" >-0.055663</td>
#       <td id="T_ff390_row1_col4" class="data row1 col4" >-0.013052</td>
#       <td id="T_ff390_row1_col5" class="data row1 col5" >-0.054402</td>
#     </tr>
#     <tr>
#       <th id="T_ff390_level0_row2" class="row_heading level0 row2" >has_actor</th>
#       <td id="T_ff390_row2_col0" class="data row2 col0" >0.158802</td>
#       <td id="T_ff390_row2_col1" class="data row2 col1" >-0.001863</td>
#       <td id="T_ff390_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ff390_row2_col3" class="data row2 col3" >0.036478</td>
#       <td id="T_ff390_row2_col4" class="data row2 col4" >0.095703</td>
#       <td id="T_ff390_row2_col5" class="data row2 col5" >0.077155</td>
#     </tr>
#     <tr>
#       <th id="T_ff390_level0_row3" class="row_heading level0 row3" >has_director</th>
#       <td id="T_ff390_row3_col0" class="data row3 col0" >0.160743</td>
#       <td id="T_ff390_row3_col1" class="data row3 col1" >-0.055663</td>
#       <td id="T_ff390_row3_col2" class="data row3 col2" >0.036478</td>
#       <td id="T_ff390_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ff390_row3_col4" class="data row3 col4" >0.083465</td>
#       <td id="T_ff390_row3_col5" class="data row3 col5" >0.081436</td>
#     </tr>
#     <tr>
#       <th id="T_ff390_level0_row4" class="row_heading level0 row4" >popularity</th>
#       <td id="T_ff390_row4_col0" class="data row4 col0" >0.344388</td>
#       <td id="T_ff390_row4_col1" class="data row4 col1" >-0.013052</td>
#       <td id="T_ff390_row4_col2" class="data row4 col2" >0.095703</td>
#       <td id="T_ff390_row4_col3" class="data row4 col3" >0.083465</td>
#       <td id="T_ff390_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_ff390_row4_col5" class="data row4 col5" >0.127282</td>
#     </tr>
#     <tr>
#       <th id="T_ff390_level0_row5" class="row_heading level0 row5" >runtime</th>
#       <td id="T_ff390_row5_col0" class="data row5 col0" >0.226170</td>
#       <td id="T_ff390_row5_col1" class="data row5 col1" >-0.054402</td>
#       <td id="T_ff390_row5_col2" class="data row5 col2" >0.077155</td>
#       <td id="T_ff390_row5_col3" class="data row5 col3" >0.081436</td>
#       <td id="T_ff390_row5_col4" class="data row5 col4" >0.127282</td>
#       <td id="T_ff390_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['feature'] = features.columns
vif['VIF'] = [variance_inflation_factor(features.values, i) for i in range(features.shape[1])]
vif
# Out:
#         feature       VIF
# 0        budget  1.688575
# 1    female_pct  3.649285
# 2     has_actor  1.054551
# 3  has_director  1.045620
# 4    popularity  1.816764
# 5       runtime  4.616885

# %% [markdown]
# We can see there are no strong correlations between the explanatory variables and the VIFs are all less than 5, so the independence assumption is satisfied and there are is no multicollinearity.
